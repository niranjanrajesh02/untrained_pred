# %%
from my_utils.model_helpers import init_model, get_layer_names, get_nice_layer_names, count_nonzero_weights
from my_utils.sparsify import sparsify_weights

# %%
resnet = init_model('vgg16', regime="trained")
resnet_s = sparsify_weights(resnet, 'vgg16', sparsity_k=0.9,)
z, t = count_nonzero_weights(resnet_s)

z/t
# Out:
# Layers to sparsify: all (n=15)
# 0.9029607169160082

# %%
sparsify_weights(convnext, 'convnext_b', target_layer_range="all")
# Out:
# Layers to sparsify: all (n=112)
# ModelWithInputLayer(
#   (input_layer): Identity()
#   (model): ConvNeXt(
#     (features): Sequential(
#       (0): Conv2dNormActivation(
#         (0): Conv2d(3, 128, kernel_size=(4, 4), stride=(4, 4))
#         (1): LayerNorm2d((128,), eps=1e-06, elementwise_affine=True)
#       )
#       (1): Sequential(
#         (0): CNBlock(
#           (block): Sequential(
#             (0): Conv2d(128, 128, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=128)
#             (1): Permute()
#             (2): LayerNorm((128,), eps=1e-06, elementwise_affine=True)
#             (3): Linear(in_features=128, out_features=512, bias=True)
#             (4): GELU(approximate='none')
#             (5): Linear(in_features=512, out_features=128, bias=True)
#             (6): Permute()
#           )
#           (stochastic_depth): StochasticDepth(p=0.0, mode=row)
#         )
#         (1): CNBlock(
#           (block): Sequential(
#             (0): Conv2d(128, 128, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=128)
#             (1): Permute()
#             (2): LayerNorm((128,), eps=1e-06, elementwise_affine=True)
#             (3): Linear(in_features=128, out_features=512, bias=True)
#             (4): GELU(approximate='none')
#             (5): Linear(in_features=512, out_features=128, bias=True)
#             (6): Permute()
#           )
#           (stochastic_depth): StochasticDepth(p=0.014285714285714285, mode=row)
#         )
#         (2): CNBlock(
#           (block): Sequential(
#             (0): Conv2d(128, 128, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=128)
#             (1): Permute()
#             (2): LayerNorm((128,), eps=1e-06, elementwise_affine=True)
#             (3): Linear(in_features=128, out_features=512, bias=True)
#             (4): GELU(approximate='none')
#             (5): Linear(in_features=512, out_features=128, bias=True)
#             (6): Permute()
#           )
#           (stochastic_depth): StochasticDepth(p=0.02857142857142857, mode=row)
#         )
#       )
#       (2): Sequential(
#         (0): LayerNorm2d((128,), eps=1e-06, elementwise_affine=True)
#         (1): Conv2d(128, 256, kernel_size=(2, 2), stride=(2, 2))
#       )
#       (3): Sequential(
#         (0): CNBlock(
#           (block): Sequential(
#             (0): Conv2d(256, 256, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=256)
#             (1): Permute()
#             (2): LayerNorm((256,), eps=1e-06, elementwise_affine=True)
#             (3): Linear(in_features=256, out_features=1024, bias=True)
#             (4): GELU(approximate='none')
#             (5): Linear(in_features=1024, out_features=256, bias=True)
#             (6): Permute()
#           )
#           (stochastic_depth): StochasticDepth(p=0.04285714285714286, mode=row)
#         )
#         (1): CNBlock(
#           (block): Sequential(
#             (0): Conv2d(256, 256, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=256)
#             (1): Permute()
#             (2): LayerNorm((256,), eps=1e-06, elementwise_affine=True)
#             (3): Linear(in_features=256, out_features=1024, bias=True)
#             (4): GELU(approximate='none')
#             (5): Linear(in_features=1024, out_features=256, bias=True)
#             (6): Permute()
#           )
#           (stochastic_depth): StochasticDepth(p=0.05714285714285714, mode=row)
#         )
#         (2): CNBlock(
#           (block): Sequential(
#             (0): Conv2d(256, 256, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=256)
#             (1): Permute()
#             (2): LayerNorm((256,), eps=1e-06, elementwise_affine=True)
#             (3): Linear(in_features=256, out_features=1024, bias=True)
#             (4): GELU(approximate='none')
#             (5): Linear(in_features=1024, out_features=256, bias=True)
#             (6): Permute()
#           )
#           (stochastic_depth): StochasticDepth(p=0.07142857142857142, mode=row)
#         )
#       )
#       (4): Sequential(
#         (0): LayerNorm2d((256,), eps=1e-06, elementwise_affine=True)
#         (1): Conv2d(256, 512, kernel_size=(2, 2), stride=(2, 2))
#       )
#       (5): Sequential(
#         (0): CNBlock(
#           (block): Sequential(
#             (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#             (1): Permute()
#             (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#             (3): Linear(in_features=512, out_features=2048, bias=True)
#             (4): GELU(approximate='none')
#             (5): Linear(in_features=2048, out_features=512, bias=True)
#             (6): Permute()
#           )
#           (stochastic_depth): StochasticDepth(p=0.08571428571428572, mode=row)
#         )
#         (1): CNBlock(
#           (block): Sequential(
#             (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#             (1): Permute()
#             (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#             (3): Linear(in_features=512, out_features=2048, bias=True)
#             (4): GELU(approximate='none')
#             (5): Linear(in_features=2048, out_features=512, bias=True)
#             (6): Permute()
#           )
#           (stochastic_depth): StochasticDepth(p=0.1, mode=row)
#         )
#         (2): CNBlock(
#           (block): Sequential(
#             (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#             (1): Permute()
#             (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#             (3): Linear(in_features=512, out_features=2048, bias=True)
#             (4): GELU(approximate='none')
#             (5): Linear(in_features=2048, out_features=512, bias=True)
#             (6): Permute()
#           )
#           (stochastic_depth): StochasticDepth(p=0.11428571428571428, mode=row)
#         )
#         (3): CNBlock(
#           (block): Sequential(
#             (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#             (1): Permute()
#             (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#             (3): Linear(in_features=512, out_features=2048, bias=True)
#             (4): GELU(approximate='none')
#             (5): Linear(in_features=2048, out_features=512, bias=True)
#             (6): Permute()
#           )
#           (stochastic_depth): StochasticDepth(p=0.12857142857142856, mode=row)
#         )
#         (4): CNBlock(
#           (block): Sequential(
#             (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#             (1): Permute()
#             (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#             (3): Linear(in_features=512, out_features=2048, bias=True)
#             (4): GELU(approximate='none')
#             (5): Linear(in_features=2048, out_features=512, bias=True)
#             (6): Permute()
#           )
#           (stochastic_depth): StochasticDepth(p=0.14285714285714285, mode=row)
#         )
#         (5): CNBlock(
#           (block): Sequential(
#             (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#             (1): Permute()
#             (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#             (3): Linear(in_features=512, out_features=2048, bias=True)
#             (4): GELU(approximate='none')
#             (5): Linear(in_features=2048, out_features=512, bias=True)
#             (6): Permute()
#           )
#           (stochastic_depth): StochasticDepth(p=0.15714285714285714, mode=row)
#         )
#         (6): CNBlock(
#           (block): Sequential(
#             (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#             (1): Permute()
#             (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#             (3): Linear(in_features=512, out_features=2048, bias=True)
#             (4): GELU(approximate='none')
#             (5): Linear(in_features=2048, out_features=512, bias=True)
#             (6): Permute()
#           )
#           (stochastic_depth): StochasticDepth(p=0.17142857142857143, mode=row)
#         )
#         (7): CNBlock(
#           (block): Sequential(
#             (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#             (1): Permute()
#             (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#             (3): Linear(in_features=512, out_features=2048, bias=True)
#             (4): GELU(approximate='none')
#             (5): Linear(in_features=2048, out_features=512, bias=True)
#             (6): Permute()
#           )
#           (stochastic_depth): StochasticDepth(p=0.18571428571428572, mode=row)
#         )
#         (8): CNBlock(
#           (block): Sequential(
#             (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#             (1): Permute()
#             (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#             (3): Linear(in_features=512, out_features=2048, bias=True)
#             (4): GELU(approximate='none')
#             (5): Linear(in_features=2048, out_features=512, bias=True)
#             (6): Permute()
#           )
#           (stochastic_depth): StochasticDepth(p=0.2, mode=row)
#         )
#         (9): CNBlock(
#           (block): Sequential(
#             (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#             (1): Permute()
#             (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#             (3): Linear(in_features=512, out_features=2048, bias=True)
#             (4): GELU(approximate='none')
#             (5): Linear(in_features=2048, out_features=512, bias=True)
#             (6): Permute()
#           )
#           (stochastic_depth): StochasticDepth(p=0.21428571428571427, mode=row)
#         )
#         (10): CNBlock(
#           (block): Sequential(
#             (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#             (1): Permute()
#             (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#             (3): Linear(in_features=512, out_features=2048, bias=True)
#             (4): GELU(approximate='none')
#             (5): Linear(in_features=2048, out_features=512, bias=True)
#             (6): Permute()
#           )
#           (stochastic_depth): StochasticDepth(p=0.22857142857142856, mode=row)
#         )
#         (11): CNBlock(
#           (block): Sequential(
#             (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#             (1): Permute()
#             (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#             (3): Linear(in_features=512, out_features=2048, bias=True)
#             (4): GELU(approximate='none')
#             (5): Linear(in_features=2048, out_features=512, bias=True)
#             (6): Permute()
#           )
#           (stochastic_depth): StochasticDepth(p=0.24285714285714285, mode=row)
#         )
#         (12): CNBlock(
#           (block): Sequential(
#             (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#             (1): Permute()
#             (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#             (3): Linear(in_features=512, out_features=2048, bias=True)
#             (4): GELU(approximate='none')
#             (5): Linear(in_features=2048, out_features=512, bias=True)
#             (6): Permute()
#           )
#           (stochastic_depth): StochasticDepth(p=0.2571428571428571, mode=row)
#         )
#         (13): CNBlock(
#           (block): Sequential(
#             (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#             (1): Permute()
#             (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#             (3): Linear(in_features=512, out_features=2048, bias=True)
#             (4): GELU(approximate='none')
#             (5): Linear(in_features=2048, out_features=512, bias=True)
#             (6): Permute()
#           )
#           (stochastic_depth): StochasticDepth(p=0.2714285714285714, mode=row)
#         )
#         (14): CNBlock(
#           (block): Sequential(
#             (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#             (1): Permute()
#             (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#             (3): Linear(in_features=512, out_features=2048, bias=True)
#             (4): GELU(approximate='none')
#             (5): Linear(in_features=2048, out_features=512, bias=True)
#             (6): Permute()
#           )
#           (stochastic_depth): StochasticDepth(p=0.2857142857142857, mode=row)
#         )
#         (15): CNBlock(
#           (block): Sequential(
#             (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#             (1): Permute()
#             (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#             (3): Linear(in_features=512, out_features=2048, bias=True)
#             (4): GELU(approximate='none')
#             (5): Linear(in_features=2048, out_features=512, bias=True)
#             (6): Permute()
#           )
#           (stochastic_depth): StochasticDepth(p=0.3, mode=row)
#         )
#         (16): CNBlock(
#           (block): Sequential(
#             (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#             (1): Permute()
#             (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#             (3): Linear(in_features=512, out_features=2048, bias=True)
#             (4): GELU(approximate='none')
#             (5): Linear(in_features=2048, out_features=512, bias=True)
#             (6): Permute()
#           )
#           (stochastic_depth): StochasticDepth(p=0.3142857142857143, mode=row)
#         )
#         (17): CNBlock(
#           (block): Sequential(
#             (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#             (1): Permute()
#             (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#             (3): Linear(in_features=512, out_features=2048, bias=True)
#             (4): GELU(approximate='none')
#             (5): Linear(in_features=2048, out_features=512, bias=True)
#             (6): Permute()
#           )
#           (stochastic_depth): StochasticDepth(p=0.32857142857142857, mode=row)
#         )
#         (18): CNBlock(
#           (block): Sequential(
#             (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#             (1): Permute()
#             (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#             (3): Linear(in_features=512, out_features=2048, bias=True)
#             (4): GELU(approximate='none')
#             (5): Linear(in_features=2048, out_features=512, bias=True)
#             (6): Permute()
#           )
#           (stochastic_depth): StochasticDepth(p=0.34285714285714286, mode=row)
#         )
#         (19): CNBlock(
#           (block): Sequential(
#             (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#             (1): Permute()
#             (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#             (3): Linear(in_features=512, out_features=2048, bias=True)
#             (4): GELU(approximate='none')
#             (5): Linear(in_features=2048, out_features=512, bias=True)
#             (6): Permute()
#           )
#           (stochastic_depth): StochasticDepth(p=0.35714285714285715, mode=row)
#         )
#         (20): CNBlock(
#           (block): Sequential(
#             (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#             (1): Permute()
#             (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#             (3): Linear(in_features=512, out_features=2048, bias=True)
#             (4): GELU(approximate='none')
#             (5): Linear(in_features=2048, out_features=512, bias=True)
#             (6): Permute()
#           )
#           (stochastic_depth): StochasticDepth(p=0.37142857142857144, mode=row)
#         )
#         (21): CNBlock(
#           (block): Sequential(
#             (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#             (1): Permute()
#             (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#             (3): Linear(in_features=512, out_features=2048, bias=True)
#             (4): GELU(approximate='none')
#             (5): Linear(in_features=2048, out_features=512, bias=True)
#             (6): Permute()
#           )
#           (stochastic_depth): StochasticDepth(p=0.38571428571428573, mode=row)
#         )
#         (22): CNBlock(
#           (block): Sequential(
#             (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#             (1): Permute()
#             (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#             (3): Linear(in_features=512, out_features=2048, bias=True)
#             (4): GELU(approximate='none')
#             (5): Linear(in_features=2048, out_features=512, bias=True)
#             (6): Permute()
#           )
#           (stochastic_depth): StochasticDepth(p=0.4, mode=row)
#         )
#         (23): CNBlock(
#           (block): Sequential(
#             (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#             (1): Permute()
#             (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#             (3): Linear(in_features=512, out_features=2048, bias=True)
#             (4): GELU(approximate='none')
#             (5): Linear(in_features=2048, out_features=512, bias=True)
#             (6): Permute()
#           )
#           (stochastic_depth): StochasticDepth(p=0.4142857142857143, mode=row)
#         )
#         (24): CNBlock(
#           (block): Sequential(
#             (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#             (1): Permute()
#             (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#             (3): Linear(in_features=512, out_features=2048, bias=True)
#             (4): GELU(approximate='none')
#             (5): Linear(in_features=2048, out_features=512, bias=True)
#             (6): Permute()
#           )
#           (stochastic_depth): StochasticDepth(p=0.42857142857142855, mode=row)
#         )
#         (25): CNBlock(
#           (block): Sequential(
#             (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#             (1): Permute()
#             (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#             (3): Linear(in_features=512, out_features=2048, bias=True)
#             (4): GELU(approximate='none')
#             (5): Linear(in_features=2048, out_features=512, bias=True)
#             (6): Permute()
#           )
#           (stochastic_depth): StochasticDepth(p=0.44285714285714284, mode=row)
#         )
#         (26): CNBlock(
#           (block): Sequential(
#             (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#             (1): Permute()
#             (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#             (3): Linear(in_features=512, out_features=2048, bias=True)
#             (4): GELU(approximate='none')
#             (5): Linear(in_features=2048, out_features=512, bias=True)
#             (6): Permute()
#           )
#           (stochastic_depth): StochasticDepth(p=0.45714285714285713, mode=row)
#         )
#       )
#       (6): Sequential(
#         (0): LayerNorm2d((512,), eps=1e-06, elementwise_affine=True)
#         (1): Conv2d(512, 1024, kernel_size=(2, 2), stride=(2, 2))
#       )
#       (7): Sequential(
#         (0): CNBlock(
#           (block): Sequential(
#             (0): Conv2d(1024, 1024, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=1024)
#             (1): Permute()
#             (2): LayerNorm((1024,), eps=1e-06, elementwise_affine=True)
#             (3): Linear(in_features=1024, out_features=4096, bias=True)
#             (4): GELU(approximate='none')
#             (5): Linear(in_features=4096, out_features=1024, bias=True)
#             (6): Permute()
#           )
#           (stochastic_depth): StochasticDepth(p=0.4714285714285714, mode=row)
#         )
#         (1): CNBlock(
#           (block): Sequential(
#             (0): Conv2d(1024, 1024, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=1024)
#             (1): Permute()
#             (2): LayerNorm((1024,), eps=1e-06, elementwise_affine=True)
#             (3): Linear(in_features=1024, out_features=4096, bias=True)
#             (4): GELU(approximate='none')
#             (5): Linear(in_features=4096, out_features=1024, bias=True)
#             (6): Permute()
#           )
#           (stochastic_depth): StochasticDepth(p=0.4857142857142857, mode=row)
#         )
#         (2): CNBlock(
#           (block): Sequential(
#             (0): Conv2d(1024, 1024, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=1024)
#             (1): Permute()
#             (2): LayerNorm((1024,), eps=1e-06, elementwise_affine=True)
#             (3): Linear(in_features=1024, out_features=4096, bias=True)
#             (4): GELU(approximate='none')
#             (5): Linear(in_features=4096, out_features=1024, bias=True)
#             (6): Permute()
#           )
#           (stochastic_depth): StochasticDepth(p=0.5, mode=row)
#         )
#       )
#     )
#     (avgpool): AdaptiveAvgPool2d(output_size=1)
#     (classifier): Sequential(
#       (0): LayerNorm2d((1024,), eps=1e-06, elementwise_affine=True)
#       (1): Flatten(start_dim=1, end_dim=-1)
#       (2): Linear(in_features=1024, out_features=1000, bias=True)
#     )
#   )
# )

# %%
convnext
# Out:
# ModelWithInputLayer(
#   (input_layer): Identity()
#   (model): ConvNeXt(
#     (features): Sequential(
#       (0): Conv2dNormActivation(
#         (0): Conv2d(3, 128, kernel_size=(4, 4), stride=(4, 4))
#         (1): LayerNorm2d((128,), eps=1e-06, elementwise_affine=True)
#       )
#       (1): Sequential(
#         (0): CNBlock(
#           (block): Sequential(
#             (0): Conv2d(128, 128, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=128)
#             (1): Permute()
#             (2): LayerNorm((128,), eps=1e-06, elementwise_affine=True)
#             (3): Linear(in_features=128, out_features=512, bias=True)
#             (4): GELU(approximate='none')
#             (5): Linear(in_features=512, out_features=128, bias=True)
#             (6): Permute()
#           )
#           (stochastic_depth): StochasticDepth(p=0.0, mode=row)
#         )
#         (1): CNBlock(
#           (block): Sequential(
#             (0): Conv2d(128, 128, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=128)
#             (1): Permute()
#             (2): LayerNorm((128,), eps=1e-06, elementwise_affine=True)
#             (3): Linear(in_features=128, out_features=512, bias=True)
#             (4): GELU(approximate='none')
#             (5): Linear(in_features=512, out_features=128, bias=True)
#             (6): Permute()
#           )
#           (stochastic_depth): StochasticDepth(p=0.014285714285714285, mode=row)
#         )
#         (2): CNBlock(
#           (block): Sequential(
#             (0): Conv2d(128, 128, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=128)
#             (1): Permute()
#             (2): LayerNorm((128,), eps=1e-06, elementwise_affine=True)
#             (3): Linear(in_features=128, out_features=512, bias=True)
#             (4): GELU(approximate='none')
#             (5): Linear(in_features=512, out_features=128, bias=True)
#             (6): Permute()
#           )
#           (stochastic_depth): StochasticDepth(p=0.02857142857142857, mode=row)
#         )
#       )
#       (2): Sequential(
#         (0): LayerNorm2d((128,), eps=1e-06, elementwise_affine=True)
#         (1): Conv2d(128, 256, kernel_size=(2, 2), stride=(2, 2))
#       )
#       (3): Sequential(
#         (0): CNBlock(
#           (block): Sequential(
#             (0): Conv2d(256, 256, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=256)
#             (1): Permute()
#             (2): LayerNorm((256,), eps=1e-06, elementwise_affine=True)
#             (3): Linear(in_features=256, out_features=1024, bias=True)
#             (4): GELU(approximate='none')
#             (5): Linear(in_features=1024, out_features=256, bias=True)
#             (6): Permute()
#           )
#           (stochastic_depth): StochasticDepth(p=0.04285714285714286, mode=row)
#         )
#         (1): CNBlock(
#           (block): Sequential(
#             (0): Conv2d(256, 256, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=256)
#             (1): Permute()
#             (2): LayerNorm((256,), eps=1e-06, elementwise_affine=True)
#             (3): Linear(in_features=256, out_features=1024, bias=True)
#             (4): GELU(approximate='none')
#             (5): Linear(in_features=1024, out_features=256, bias=True)
#             (6): Permute()
#           )
#           (stochastic_depth): StochasticDepth(p=0.05714285714285714, mode=row)
#         )
#         (2): CNBlock(
#           (block): Sequential(
#             (0): Conv2d(256, 256, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=256)
#             (1): Permute()
#             (2): LayerNorm((256,), eps=1e-06, elementwise_affine=True)
#             (3): Linear(in_features=256, out_features=1024, bias=True)
#             (4): GELU(approximate='none')
#             (5): Linear(in_features=1024, out_features=256, bias=True)
#             (6): Permute()
#           )
#           (stochastic_depth): StochasticDepth(p=0.07142857142857142, mode=row)
#         )
#       )
#       (4): Sequential(
#         (0): LayerNorm2d((256,), eps=1e-06, elementwise_affine=True)
#         (1): Conv2d(256, 512, kernel_size=(2, 2), stride=(2, 2))
#       )
#       (5): Sequential(
#         (0): CNBlock(
#           (block): Sequential(
#             (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#             (1): Permute()
#             (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#             (3): Linear(in_features=512, out_features=2048, bias=True)
#             (4): GELU(approximate='none')
#             (5): Linear(in_features=2048, out_features=512, bias=True)
#             (6): Permute()
#           )
#           (stochastic_depth): StochasticDepth(p=0.08571428571428572, mode=row)
#         )
#         (1): CNBlock(
#           (block): Sequential(
#             (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#             (1): Permute()
#             (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#             (3): Linear(in_features=512, out_features=2048, bias=True)
#             (4): GELU(approximate='none')
#             (5): Linear(in_features=2048, out_features=512, bias=True)
#             (6): Permute()
#           )
#           (stochastic_depth): StochasticDepth(p=0.1, mode=row)
#         )
#         (2): CNBlock(
#           (block): Sequential(
#             (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#             (1): Permute()
#             (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#             (3): Linear(in_features=512, out_features=2048, bias=True)
#             (4): GELU(approximate='none')
#             (5): Linear(in_features=2048, out_features=512, bias=True)
#             (6): Permute()
#           )
#           (stochastic_depth): StochasticDepth(p=0.11428571428571428, mode=row)
#         )
#         (3): CNBlock(
#           (block): Sequential(
#             (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#             (1): Permute()
#             (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#             (3): Linear(in_features=512, out_features=2048, bias=True)
#             (4): GELU(approximate='none')
#             (5): Linear(in_features=2048, out_features=512, bias=True)
#             (6): Permute()
#           )
#           (stochastic_depth): StochasticDepth(p=0.12857142857142856, mode=row)
#         )
#         (4): CNBlock(
#           (block): Sequential(
#             (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#             (1): Permute()
#             (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#             (3): Linear(in_features=512, out_features=2048, bias=True)
#             (4): GELU(approximate='none')
#             (5): Linear(in_features=2048, out_features=512, bias=True)
#             (6): Permute()
#           )
#           (stochastic_depth): StochasticDepth(p=0.14285714285714285, mode=row)
#         )
#         (5): CNBlock(
#           (block): Sequential(
#             (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#             (1): Permute()
#             (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#             (3): Linear(in_features=512, out_features=2048, bias=True)
#             (4): GELU(approximate='none')
#             (5): Linear(in_features=2048, out_features=512, bias=True)
#             (6): Permute()
#           )
#           (stochastic_depth): StochasticDepth(p=0.15714285714285714, mode=row)
#         )
#         (6): CNBlock(
#           (block): Sequential(
#             (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#             (1): Permute()
#             (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#             (3): Linear(in_features=512, out_features=2048, bias=True)
#             (4): GELU(approximate='none')
#             (5): Linear(in_features=2048, out_features=512, bias=True)
#             (6): Permute()
#           )
#           (stochastic_depth): StochasticDepth(p=0.17142857142857143, mode=row)
#         )
#         (7): CNBlock(
#           (block): Sequential(
#             (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#             (1): Permute()
#             (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#             (3): Linear(in_features=512, out_features=2048, bias=True)
#             (4): GELU(approximate='none')
#             (5): Linear(in_features=2048, out_features=512, bias=True)
#             (6): Permute()
#           )
#           (stochastic_depth): StochasticDepth(p=0.18571428571428572, mode=row)
#         )
#         (8): CNBlock(
#           (block): Sequential(
#             (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#             (1): Permute()
#             (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#             (3): Linear(in_features=512, out_features=2048, bias=True)
#             (4): GELU(approximate='none')
#             (5): Linear(in_features=2048, out_features=512, bias=True)
#             (6): Permute()
#           )
#           (stochastic_depth): StochasticDepth(p=0.2, mode=row)
#         )
#         (9): CNBlock(
#           (block): Sequential(
#             (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#             (1): Permute()
#             (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#             (3): Linear(in_features=512, out_features=2048, bias=True)
#             (4): GELU(approximate='none')
#             (5): Linear(in_features=2048, out_features=512, bias=True)
#             (6): Permute()
#           )
#           (stochastic_depth): StochasticDepth(p=0.21428571428571427, mode=row)
#         )
#         (10): CNBlock(
#           (block): Sequential(
#             (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#             (1): Permute()
#             (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#             (3): Linear(in_features=512, out_features=2048, bias=True)
#             (4): GELU(approximate='none')
#             (5): Linear(in_features=2048, out_features=512, bias=True)
#             (6): Permute()
#           )
#           (stochastic_depth): StochasticDepth(p=0.22857142857142856, mode=row)
#         )
#         (11): CNBlock(
#           (block): Sequential(
#             (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#             (1): Permute()
#             (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#             (3): Linear(in_features=512, out_features=2048, bias=True)
#             (4): GELU(approximate='none')
#             (5): Linear(in_features=2048, out_features=512, bias=True)
#             (6): Permute()
#           )
#           (stochastic_depth): StochasticDepth(p=0.24285714285714285, mode=row)
#         )
#         (12): CNBlock(
#           (block): Sequential(
#             (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#             (1): Permute()
#             (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#             (3): Linear(in_features=512, out_features=2048, bias=True)
#             (4): GELU(approximate='none')
#             (5): Linear(in_features=2048, out_features=512, bias=True)
#             (6): Permute()
#           )
#           (stochastic_depth): StochasticDepth(p=0.2571428571428571, mode=row)
#         )
#         (13): CNBlock(
#           (block): Sequential(
#             (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#             (1): Permute()
#             (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#             (3): Linear(in_features=512, out_features=2048, bias=True)
#             (4): GELU(approximate='none')
#             (5): Linear(in_features=2048, out_features=512, bias=True)
#             (6): Permute()
#           )
#           (stochastic_depth): StochasticDepth(p=0.2714285714285714, mode=row)
#         )
#         (14): CNBlock(
#           (block): Sequential(
#             (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#             (1): Permute()
#             (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#             (3): Linear(in_features=512, out_features=2048, bias=True)
#             (4): GELU(approximate='none')
#             (5): Linear(in_features=2048, out_features=512, bias=True)
#             (6): Permute()
#           )
#           (stochastic_depth): StochasticDepth(p=0.2857142857142857, mode=row)
#         )
#         (15): CNBlock(
#           (block): Sequential(
#             (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#             (1): Permute()
#             (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#             (3): Linear(in_features=512, out_features=2048, bias=True)
#             (4): GELU(approximate='none')
#             (5): Linear(in_features=2048, out_features=512, bias=True)
#             (6): Permute()
#           )
#           (stochastic_depth): StochasticDepth(p=0.3, mode=row)
#         )
#         (16): CNBlock(
#           (block): Sequential(
#             (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#             (1): Permute()
#             (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#             (3): Linear(in_features=512, out_features=2048, bias=True)
#             (4): GELU(approximate='none')
#             (5): Linear(in_features=2048, out_features=512, bias=True)
#             (6): Permute()
#           )
#           (stochastic_depth): StochasticDepth(p=0.3142857142857143, mode=row)
#         )
#         (17): CNBlock(
#           (block): Sequential(
#             (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#             (1): Permute()
#             (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#             (3): Linear(in_features=512, out_features=2048, bias=True)
#             (4): GELU(approximate='none')
#             (5): Linear(in_features=2048, out_features=512, bias=True)
#             (6): Permute()
#           )
#           (stochastic_depth): StochasticDepth(p=0.32857142857142857, mode=row)
#         )
#         (18): CNBlock(
#           (block): Sequential(
#             (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#             (1): Permute()
#             (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#             (3): Linear(in_features=512, out_features=2048, bias=True)
#             (4): GELU(approximate='none')
#             (5): Linear(in_features=2048, out_features=512, bias=True)
#             (6): Permute()
#           )
#           (stochastic_depth): StochasticDepth(p=0.34285714285714286, mode=row)
#         )
#         (19): CNBlock(
#           (block): Sequential(
#             (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#             (1): Permute()
#             (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#             (3): Linear(in_features=512, out_features=2048, bias=True)
#             (4): GELU(approximate='none')
#             (5): Linear(in_features=2048, out_features=512, bias=True)
#             (6): Permute()
#           )
#           (stochastic_depth): StochasticDepth(p=0.35714285714285715, mode=row)
#         )
#         (20): CNBlock(
#           (block): Sequential(
#             (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#             (1): Permute()
#             (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#             (3): Linear(in_features=512, out_features=2048, bias=True)
#             (4): GELU(approximate='none')
#             (5): Linear(in_features=2048, out_features=512, bias=True)
#             (6): Permute()
#           )
#           (stochastic_depth): StochasticDepth(p=0.37142857142857144, mode=row)
#         )
#         (21): CNBlock(
#           (block): Sequential(
#             (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#             (1): Permute()
#             (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#             (3): Linear(in_features=512, out_features=2048, bias=True)
#             (4): GELU(approximate='none')
#             (5): Linear(in_features=2048, out_features=512, bias=True)
#             (6): Permute()
#           )
#           (stochastic_depth): StochasticDepth(p=0.38571428571428573, mode=row)
#         )
#         (22): CNBlock(
#           (block): Sequential(
#             (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#             (1): Permute()
#             (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#             (3): Linear(in_features=512, out_features=2048, bias=True)
#             (4): GELU(approximate='none')
#             (5): Linear(in_features=2048, out_features=512, bias=True)
#             (6): Permute()
#           )
#           (stochastic_depth): StochasticDepth(p=0.4, mode=row)
#         )
#         (23): CNBlock(
#           (block): Sequential(
#             (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#             (1): Permute()
#             (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#             (3): Linear(in_features=512, out_features=2048, bias=True)
#             (4): GELU(approximate='none')
#             (5): Linear(in_features=2048, out_features=512, bias=True)
#             (6): Permute()
#           )
#           (stochastic_depth): StochasticDepth(p=0.4142857142857143, mode=row)
#         )
#         (24): CNBlock(
#           (block): Sequential(
#             (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#             (1): Permute()
#             (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#             (3): Linear(in_features=512, out_features=2048, bias=True)
#             (4): GELU(approximate='none')
#             (5): Linear(in_features=2048, out_features=512, bias=True)
#             (6): Permute()
#           )
#           (stochastic_depth): StochasticDepth(p=0.42857142857142855, mode=row)
#         )
#         (25): CNBlock(
#           (block): Sequential(
#             (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#             (1): Permute()
#             (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#             (3): Linear(in_features=512, out_features=2048, bias=True)
#             (4): GELU(approximate='none')
#             (5): Linear(in_features=2048, out_features=512, bias=True)
#             (6): Permute()
#           )
#           (stochastic_depth): StochasticDepth(p=0.44285714285714284, mode=row)
#         )
#         (26): CNBlock(
#           (block): Sequential(
#             (0): Conv2d(512, 512, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=512)
#             (1): Permute()
#             (2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#             (3): Linear(in_features=512, out_features=2048, bias=True)
#             (4): GELU(approximate='none')
#             (5): Linear(in_features=2048, out_features=512, bias=True)
#             (6): Permute()
#           )
#           (stochastic_depth): StochasticDepth(p=0.45714285714285713, mode=row)
#         )
#       )
#       (6): Sequential(
#         (0): LayerNorm2d((512,), eps=1e-06, elementwise_affine=True)
#         (1): Conv2d(512, 1024, kernel_size=(2, 2), stride=(2, 2))
#       )
#       (7): Sequential(
#         (0): CNBlock(
#           (block): Sequential(
#             (0): Conv2d(1024, 1024, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=1024)
#             (1): Permute()
#             (2): LayerNorm((1024,), eps=1e-06, elementwise_affine=True)
#             (3): Linear(in_features=1024, out_features=4096, bias=True)
#             (4): GELU(approximate='none')
#             (5): Linear(in_features=4096, out_features=1024, bias=True)
#             (6): Permute()
#           )
#           (stochastic_depth): StochasticDepth(p=0.4714285714285714, mode=row)
#         )
#         (1): CNBlock(
#           (block): Sequential(
#             (0): Conv2d(1024, 1024, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=1024)
#             (1): Permute()
#             (2): LayerNorm((1024,), eps=1e-06, elementwise_affine=True)
#             (3): Linear(in_features=1024, out_features=4096, bias=True)
#             (4): GELU(approximate='none')
#             (5): Linear(in_features=4096, out_features=1024, bias=True)
#             (6): Permute()
#           )
#           (stochastic_depth): StochasticDepth(p=0.4857142857142857, mode=row)
#         )
#         (2): CNBlock(
#           (block): Sequential(
#             (0): Conv2d(1024, 1024, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=1024)
#             (1): Permute()
#             (2): LayerNorm((1024,), eps=1e-06, elementwise_affine=True)
#             (3): Linear(in_features=1024, out_features=4096, bias=True)
#             (4): GELU(approximate='none')
#             (5): Linear(in_features=4096, out_features=1024, bias=True)
#             (6): Permute()
#           )
#           (stochastic_depth): StochasticDepth(p=0.5, mode=row)
#         )
#       )
#     )
#     (avgpool): AdaptiveAvgPool2d(output_size=1)
#     (classifier): Sequential(
#       (0): LayerNorm2d((1024,), eps=1e-06, elementwise_affine=True)
#       (1): Flatten(start_dim=1, end_dim=-1)
#       (2): Linear(in_features=1024, out_features=1000, bias=True)
#     )
#   )
# )

# %%
print(vit.model.encoder.layers.encoder_layer_1.self_attention.in_proj_weight.shape)
print(vit.model.encoder.layers.encoder_layer_1.self_attention.out_proj.weight.shape)
# Out:
# torch.Size([2304, 768])
# torch.Size([768, 768])

# %%
ln = get_layer_names(convnext)
get_nice_layer_names(convnext, ln)
for name, module in convnext.named_modules():
    if len(list(module.children())) == 0:
        print(f"{name} ||||  {str(module).split("(")[0]}")
# Out:
# input_layer ||||  Identity
# model.features.0.0 ||||  Conv2d
# model.features.0.1 ||||  LayerNorm2d
# model.features.1.0.block.0 ||||  Conv2d
# model.features.1.0.block.1 ||||  Permute
# model.features.1.0.block.2 ||||  LayerNorm
# model.features.1.0.block.3 ||||  Linear
# model.features.1.0.block.4 ||||  GELU
# model.features.1.0.block.5 ||||  Linear
# model.features.1.0.block.6 ||||  Permute
# model.features.1.0.stochastic_depth ||||  StochasticDepth
# model.features.1.1.block.0 ||||  Conv2d
# model.features.1.1.block.1 ||||  Permute
# model.features.1.1.block.2 ||||  LayerNorm
# model.features.1.1.block.3 ||||  Linear
# model.features.1.1.block.4 ||||  GELU
# model.features.1.1.block.5 ||||  Linear
# model.features.1.1.block.6 ||||  Permute
# model.features.1.1.stochastic_depth ||||  StochasticDepth
# model.features.1.2.block.0 ||||  Conv2d
# model.features.1.2.block.1 ||||  Permute
# model.features.1.2.block.2 ||||  LayerNorm
# model.features.1.2.block.3 ||||  Linear
# model.features.1.2.block.4 ||||  GELU
# model.features.1.2.block.5 ||||  Linear
# model.features.1.2.block.6 ||||  Permute
# model.features.1.2.stochastic_depth ||||  StochasticDepth
# model.features.2.0 ||||  LayerNorm2d
# model.features.2.1 ||||  Conv2d
# model.features.3.0.block.0 ||||  Conv2d
# model.features.3.0.block.1 ||||  Permute
# model.features.3.0.block.2 ||||  LayerNorm
# model.features.3.0.block.3 ||||  Linear
# model.features.3.0.block.4 ||||  GELU
# model.features.3.0.block.5 ||||  Linear
# model.features.3.0.block.6 ||||  Permute
# model.features.3.0.stochastic_depth ||||  StochasticDepth
# model.features.3.1.block.0 ||||  Conv2d
# model.features.3.1.block.1 ||||  Permute
# model.features.3.1.block.2 ||||  LayerNorm
# model.features.3.1.block.3 ||||  Linear
# model.features.3.1.block.4 ||||  GELU
# model.features.3.1.block.5 ||||  Linear
# model.features.3.1.block.6 ||||  Permute
# model.features.3.1.stochastic_depth ||||  StochasticDepth
# model.features.3.2.block.0 ||||  Conv2d
# model.features.3.2.block.1 ||||  Permute
# model.features.3.2.block.2 ||||  LayerNorm
# model.features.3.2.block.3 ||||  Linear
# model.features.3.2.block.4 ||||  GELU
# model.features.3.2.block.5 ||||  Linear
# model.features.3.2.block.6 ||||  Permute
# model.features.3.2.stochastic_depth ||||  StochasticDepth
# model.features.4.0 ||||  LayerNorm2d
# model.features.4.1 ||||  Conv2d
# model.features.5.0.block.0 ||||  Conv2d
# model.features.5.0.block.1 ||||  Permute
# model.features.5.0.block.2 ||||  LayerNorm
# model.features.5.0.block.3 ||||  Linear
# model.features.5.0.block.4 ||||  GELU
# model.features.5.0.block.5 ||||  Linear
# model.features.5.0.block.6 ||||  Permute
# model.features.5.0.stochastic_depth ||||  StochasticDepth
# model.features.5.1.block.0 ||||  Conv2d
# model.features.5.1.block.1 ||||  Permute
# model.features.5.1.block.2 ||||  LayerNorm
# model.features.5.1.block.3 ||||  Linear
# model.features.5.1.block.4 ||||  GELU
# model.features.5.1.block.5 ||||  Linear
# model.features.5.1.block.6 ||||  Permute
# model.features.5.1.stochastic_depth ||||  StochasticDepth
# model.features.5.2.block.0 ||||  Conv2d
# model.features.5.2.block.1 ||||  Permute
# model.features.5.2.block.2 ||||  LayerNorm
# model.features.5.2.block.3 ||||  Linear
# model.features.5.2.block.4 ||||  GELU
# model.features.5.2.block.5 ||||  Linear
# model.features.5.2.block.6 ||||  Permute
# model.features.5.2.stochastic_depth ||||  StochasticDepth
# model.features.5.3.block.0 ||||  Conv2d
# model.features.5.3.block.1 ||||  Permute
# model.features.5.3.block.2 ||||  LayerNorm
# model.features.5.3.block.3 ||||  Linear
# model.features.5.3.block.4 ||||  GELU
# model.features.5.3.block.5 ||||  Linear
# model.features.5.3.block.6 ||||  Permute
# model.features.5.3.stochastic_depth ||||  StochasticDepth
# model.features.5.4.block.0 ||||  Conv2d
# model.features.5.4.block.1 ||||  Permute
# model.features.5.4.block.2 ||||  LayerNorm
# model.features.5.4.block.3 ||||  Linear
# model.features.5.4.block.4 ||||  GELU
# model.features.5.4.block.5 ||||  Linear
# model.features.5.4.block.6 ||||  Permute
# model.features.5.4.stochastic_depth ||||  StochasticDepth
# model.features.5.5.block.0 ||||  Conv2d
# model.features.5.5.block.1 ||||  Permute
# model.features.5.5.block.2 ||||  LayerNorm
# model.features.5.5.block.3 ||||  Linear
# model.features.5.5.block.4 ||||  GELU
# model.features.5.5.block.5 ||||  Linear
# model.features.5.5.block.6 ||||  Permute
# model.features.5.5.stochastic_depth ||||  StochasticDepth
# model.features.5.6.block.0 ||||  Conv2d
# model.features.5.6.block.1 ||||  Permute
# model.features.5.6.block.2 ||||  LayerNorm
# model.features.5.6.block.3 ||||  Linear
# model.features.5.6.block.4 ||||  GELU
# model.features.5.6.block.5 ||||  Linear
# model.features.5.6.block.6 ||||  Permute
# model.features.5.6.stochastic_depth ||||  StochasticDepth
# model.features.5.7.block.0 ||||  Conv2d
# model.features.5.7.block.1 ||||  Permute
# model.features.5.7.block.2 ||||  LayerNorm
# model.features.5.7.block.3 ||||  Linear
# model.features.5.7.block.4 ||||  GELU
# model.features.5.7.block.5 ||||  Linear
# model.features.5.7.block.6 ||||  Permute
# model.features.5.7.stochastic_depth ||||  StochasticDepth
# model.features.5.8.block.0 ||||  Conv2d
# model.features.5.8.block.1 ||||  Permute
# model.features.5.8.block.2 ||||  LayerNorm
# model.features.5.8.block.3 ||||  Linear
# model.features.5.8.block.4 ||||  GELU
# model.features.5.8.block.5 ||||  Linear
# model.features.5.8.block.6 ||||  Permute
# model.features.5.8.stochastic_depth ||||  StochasticDepth
# model.features.5.9.block.0 ||||  Conv2d
# model.features.5.9.block.1 ||||  Permute
# model.features.5.9.block.2 ||||  LayerNorm
# model.features.5.9.block.3 ||||  Linear
# model.features.5.9.block.4 ||||  GELU
# model.features.5.9.block.5 ||||  Linear
# model.features.5.9.block.6 ||||  Permute
# model.features.5.9.stochastic_depth ||||  StochasticDepth
# model.features.5.10.block.0 ||||  Conv2d
# model.features.5.10.block.1 ||||  Permute
# model.features.5.10.block.2 ||||  LayerNorm
# model.features.5.10.block.3 ||||  Linear
# model.features.5.10.block.4 ||||  GELU
# model.features.5.10.block.5 ||||  Linear
# model.features.5.10.block.6 ||||  Permute
# model.features.5.10.stochastic_depth ||||  StochasticDepth
# model.features.5.11.block.0 ||||  Conv2d
# model.features.5.11.block.1 ||||  Permute
# model.features.5.11.block.2 ||||  LayerNorm
# model.features.5.11.block.3 ||||  Linear
# model.features.5.11.block.4 ||||  GELU
# model.features.5.11.block.5 ||||  Linear
# model.features.5.11.block.6 ||||  Permute
# model.features.5.11.stochastic_depth ||||  StochasticDepth
# model.features.5.12.block.0 ||||  Conv2d
# model.features.5.12.block.1 ||||  Permute
# model.features.5.12.block.2 ||||  LayerNorm
# model.features.5.12.block.3 ||||  Linear
# model.features.5.12.block.4 ||||  GELU
# model.features.5.12.block.5 ||||  Linear
# model.features.5.12.block.6 ||||  Permute
# model.features.5.12.stochastic_depth ||||  StochasticDepth
# model.features.5.13.block.0 ||||  Conv2d
# model.features.5.13.block.1 ||||  Permute
# model.features.5.13.block.2 ||||  LayerNorm
# model.features.5.13.block.3 ||||  Linear
# model.features.5.13.block.4 ||||  GELU
# model.features.5.13.block.5 ||||  Linear
# model.features.5.13.block.6 ||||  Permute
# model.features.5.13.stochastic_depth ||||  StochasticDepth
# model.features.5.14.block.0 ||||  Conv2d
# model.features.5.14.block.1 ||||  Permute
# model.features.5.14.block.2 ||||  LayerNorm
# model.features.5.14.block.3 ||||  Linear
# model.features.5.14.block.4 ||||  GELU
# model.features.5.14.block.5 ||||  Linear
# model.features.5.14.block.6 ||||  Permute
# model.features.5.14.stochastic_depth ||||  StochasticDepth
# model.features.5.15.block.0 ||||  Conv2d
# model.features.5.15.block.1 ||||  Permute
# model.features.5.15.block.2 ||||  LayerNorm
# model.features.5.15.block.3 ||||  Linear
# model.features.5.15.block.4 ||||  GELU
# model.features.5.15.block.5 ||||  Linear
# model.features.5.15.block.6 ||||  Permute
# model.features.5.15.stochastic_depth ||||  StochasticDepth
# model.features.5.16.block.0 ||||  Conv2d
# model.features.5.16.block.1 ||||  Permute
# model.features.5.16.block.2 ||||  LayerNorm
# model.features.5.16.block.3 ||||  Linear
# model.features.5.16.block.4 ||||  GELU
# model.features.5.16.block.5 ||||  Linear
# model.features.5.16.block.6 ||||  Permute
# model.features.5.16.stochastic_depth ||||  StochasticDepth
# model.features.5.17.block.0 ||||  Conv2d
# model.features.5.17.block.1 ||||  Permute
# model.features.5.17.block.2 ||||  LayerNorm
# model.features.5.17.block.3 ||||  Linear
# model.features.5.17.block.4 ||||  GELU
# model.features.5.17.block.5 ||||  Linear
# model.features.5.17.block.6 ||||  Permute
# model.features.5.17.stochastic_depth ||||  StochasticDepth
# model.features.5.18.block.0 ||||  Conv2d
# model.features.5.18.block.1 ||||  Permute
# model.features.5.18.block.2 ||||  LayerNorm
# model.features.5.18.block.3 ||||  Linear
# model.features.5.18.block.4 ||||  GELU
# model.features.5.18.block.5 ||||  Linear
# model.features.5.18.block.6 ||||  Permute
# model.features.5.18.stochastic_depth ||||  StochasticDepth
# model.features.5.19.block.0 ||||  Conv2d
# model.features.5.19.block.1 ||||  Permute
# model.features.5.19.block.2 ||||  LayerNorm
# model.features.5.19.block.3 ||||  Linear
# model.features.5.19.block.4 ||||  GELU
# model.features.5.19.block.5 ||||  Linear
# model.features.5.19.block.6 ||||  Permute
# model.features.5.19.stochastic_depth ||||  StochasticDepth
# model.features.5.20.block.0 ||||  Conv2d
# model.features.5.20.block.1 ||||  Permute
# model.features.5.20.block.2 ||||  LayerNorm
# model.features.5.20.block.3 ||||  Linear
# model.features.5.20.block.4 ||||  GELU
# model.features.5.20.block.5 ||||  Linear
# model.features.5.20.block.6 ||||  Permute
# model.features.5.20.stochastic_depth ||||  StochasticDepth
# model.features.5.21.block.0 ||||  Conv2d
# model.features.5.21.block.1 ||||  Permute
# model.features.5.21.block.2 ||||  LayerNorm
# model.features.5.21.block.3 ||||  Linear
# model.features.5.21.block.4 ||||  GELU
# model.features.5.21.block.5 ||||  Linear
# model.features.5.21.block.6 ||||  Permute
# model.features.5.21.stochastic_depth ||||  StochasticDepth
# model.features.5.22.block.0 ||||  Conv2d
# model.features.5.22.block.1 ||||  Permute
# model.features.5.22.block.2 ||||  LayerNorm
# model.features.5.22.block.3 ||||  Linear
# model.features.5.22.block.4 ||||  GELU
# model.features.5.22.block.5 ||||  Linear
# model.features.5.22.block.6 ||||  Permute
# model.features.5.22.stochastic_depth ||||  StochasticDepth
# model.features.5.23.block.0 ||||  Conv2d
# model.features.5.23.block.1 ||||  Permute
# model.features.5.23.block.2 ||||  LayerNorm
# model.features.5.23.block.3 ||||  Linear
# model.features.5.23.block.4 ||||  GELU
# model.features.5.23.block.5 ||||  Linear
# model.features.5.23.block.6 ||||  Permute
# model.features.5.23.stochastic_depth ||||  StochasticDepth
# model.features.5.24.block.0 ||||  Conv2d
# model.features.5.24.block.1 ||||  Permute
# model.features.5.24.block.2 ||||  LayerNorm
# model.features.5.24.block.3 ||||  Linear
# model.features.5.24.block.4 ||||  GELU
# model.features.5.24.block.5 ||||  Linear
# model.features.5.24.block.6 ||||  Permute
# model.features.5.24.stochastic_depth ||||  StochasticDepth
# model.features.5.25.block.0 ||||  Conv2d
# model.features.5.25.block.1 ||||  Permute
# model.features.5.25.block.2 ||||  LayerNorm
# model.features.5.25.block.3 ||||  Linear
# model.features.5.25.block.4 ||||  GELU
# model.features.5.25.block.5 ||||  Linear
# model.features.5.25.block.6 ||||  Permute
# model.features.5.25.stochastic_depth ||||  StochasticDepth
# model.features.5.26.block.0 ||||  Conv2d
# model.features.5.26.block.1 ||||  Permute
# model.features.5.26.block.2 ||||  LayerNorm
# model.features.5.26.block.3 ||||  Linear
# model.features.5.26.block.4 ||||  GELU
# model.features.5.26.block.5 ||||  Linear
# model.features.5.26.block.6 ||||  Permute
# model.features.5.26.stochastic_depth ||||  StochasticDepth
# model.features.6.0 ||||  LayerNorm2d
# model.features.6.1 ||||  Conv2d
# model.features.7.0.block.0 ||||  Conv2d
# model.features.7.0.block.1 ||||  Permute
# model.features.7.0.block.2 ||||  LayerNorm
# model.features.7.0.block.3 ||||  Linear
# model.features.7.0.block.4 ||||  GELU
# model.features.7.0.block.5 ||||  Linear
# model.features.7.0.block.6 ||||  Permute
# model.features.7.0.stochastic_depth ||||  StochasticDepth
# model.features.7.1.block.0 ||||  Conv2d
# model.features.7.1.block.1 ||||  Permute
# model.features.7.1.block.2 ||||  LayerNorm
# model.features.7.1.block.3 ||||  Linear
# model.features.7.1.block.4 ||||  GELU
# model.features.7.1.block.5 ||||  Linear
# model.features.7.1.block.6 ||||  Permute
# model.features.7.1.stochastic_depth ||||  StochasticDepth
# model.features.7.2.block.0 ||||  Conv2d
# model.features.7.2.block.1 ||||  Permute
# model.features.7.2.block.2 ||||  LayerNorm
# model.features.7.2.block.3 ||||  Linear
# model.features.7.2.block.4 ||||  GELU
# model.features.7.2.block.5 ||||  Linear
# model.features.7.2.block.6 ||||  Permute
# model.features.7.2.stochastic_depth ||||  StochasticDepth
# model.avgpool ||||  AdaptiveAvgPool2d
# model.classifier.0 ||||  LayerNorm2d
# model.classifier.1 ||||  Flatten
# model.classifier.2 ||||  Linear

# %%
import torch
import random
import numpy as np
from torch import nn
from torchvision import models

def sparsify_vit_weights(model, sparsity_k=0.5, layers="all", layer_type="all"):

    assert 0.0 <= sparsity_k <= 1.0, "sparsity_k must be between 0 and 1."
    assert layer_type in ["all", "attn_in", "attn_out", "mlp"], "layer_type must be one of 'all', 'attn_in', 'attn_out', 'mlp'."

    layer_names = []
    mlp_flag = layer_type in ["all", "mlp"]
    attn_in_flag = layer_type in ["all", "attn_in"]
    attn_out_flag = layer_type in ["all", "attn_out"]


    # for now only "all" layers supported
    for name, module in model.named_modules():
        if isinstance(module, (nn.Linear)):
            # mlp layers
            if mlp_flag and 'mlp' in name:
                layer_names.append(name)
            
            # attn_out layers
            if attn_out_flag and 'out_proj' in name:
                layer_names.append(name) 
        
        # attn_in layers
        if attn_in_flag and isinstance(module, nn.MultiheadAttention):
            layer_names.append(name) # needs special attention later to get in_proj

    layer_names = layer_names  # exclude the final classification layer
    num_layers = len(layer_names)

    layers_to_sparsify = layer_names  # all layers TODO: add early/late options
    return layer_names
    modules = dict(model.named_modules())
    for name in layers_to_sparsify:
        module = modules[name]
        W = None
        if isinstance(module, (nn.Linear)):
            # mlp layers and attn_out layers
            W = module.weight
            
        
        # attn_in layers
        elif isinstance(module, nn.MultiheadAttention):
            W = module.in_proj_weight
            
        if W is not None:
            with torch.no_grad():
                W_flat = W.view(-1)
                num_weights_to_keep = round(sparsity_k * W_flat.numel())
                indices = torch.randperm(W_flat.numel())[:num_weights_to_keep]
                mask = torch.zeros_like(W_flat)
                mask[indices] = 1
                W_sparse = (W_flat * mask).view_as(W)
                
                if isinstance(module, (nn.Linear)):
                    module.weight.copy_(W_sparse)
                elif isinstance(module, nn.MultiheadAttention):
                    module.in_proj_weight.copy_(W_sparse)

            # Verify sparsity to be within tolerance (5%)
            actual_nonzero = torch.sum(W != 0).item()
            actual_sparsity = actual_nonzero / W.numel() # fraction of weights kept
            print(f'Layer {name}: expected sparsity {sparsity_k}, actual sparsity {actual_sparsity}')
            assert abs(actual_sparsity - sparsity_k) < 0.05, f"Sparsity check failed for layer {name}: expected {sparsity_k}, got {actual_sparsity}"

# %%
vit = init_model('vit_b_16', regime="trained")
ln = sparsify_vit_weights(vit, layer_type="all")
print(f"All layers: {len(ln)}")
vit = init_model('vit_b_16', regime="trained")
ln1 = sparsify_vit_weights(vit, layer_type="attn_in")
print(f"AttnIn layers: {len(ln1)}")
vit = init_model('vit_b_16', regime="trained")
ln2 = sparsify_vit_weights(vit, layer_type="attn_out")
print(f"AttnOut layers: {len(ln2)}")
vit = init_model('vit_b_16', regime="trained")
ln3 = sparsify_vit_weights(vit, layer_type="mlp")
print(f"MLP layers: {len(ln3)}")

# %%
net = init_model('vit_b_16', regime="trained")
nets = sparsify_weights(net, arch='vit_b_16', target_layer_range="middle")
# Out:
# ['model.conv_proj', 'model.encoder.layers.encoder_layer_0.self_attention', 'model.encoder.layers.encoder_layer_0.self_attention.out_proj', 'model.encoder.layers.encoder_layer_0.mlp.0', 'model.encoder.layers.encoder_layer_0.mlp.3', 'model.encoder.layers.encoder_layer_1.self_attention', 'model.encoder.layers.encoder_layer_1.self_attention.out_proj', 'model.encoder.layers.encoder_layer_1.mlp.0', 'model.encoder.layers.encoder_layer_1.mlp.3', 'model.encoder.layers.encoder_layer_2.self_attention', 'model.encoder.layers.encoder_layer_2.self_attention.out_proj', 'model.encoder.layers.encoder_layer_2.mlp.0', 'model.encoder.layers.encoder_layer_2.mlp.3', 'model.encoder.layers.encoder_layer_3.self_attention', 'model.encoder.layers.encoder_layer_3.self_attention.out_proj', 'model.encoder.layers.encoder_layer_3.mlp.0', 'model.encoder.layers.encoder_layer_3.mlp.3', 'model.encoder.layers.encoder_layer_4.self_attention', 'model.encoder.layers.encoder_layer_4.self_attention.out_proj', 'model.encoder.layers.encoder_layer_4.mlp.0', 'model.encoder.layers.encoder_layer_4.mlp.3', 'model.encoder.layers.encoder_layer_5.self_attention', 'model.encoder.layers.encoder_layer_5.self_attention.out_proj', 'model.encoder.layers.encoder_layer_5.mlp.0', 'model.encoder.layers.encoder_layer_5.mlp.3', 'model.encoder.layers.encoder_layer_6.self_attention', 'model.encoder.layers.encoder_layer_6.self_attention.out_proj', 'model.encoder.layers.encoder_layer_6.mlp.0', 'model.encoder.layers.encoder_layer_6.mlp.3', 'model.encoder.layers.encoder_layer_7.self_attention', 'model.encoder.layers.encoder_layer_7.self_attention.out_proj', 'model.encoder.layers.encoder_layer_7.mlp.0', 'model.encoder.layers.encoder_layer_7.mlp.3', 'model.encoder.layers.encoder_layer_8.self_attention', 'model.encoder.layers.encoder_layer_8.self_attention.out_proj', 'model.encoder.layers.encoder_layer_8.mlp.0', 'model.encoder.layers.encoder_layer_8.mlp.3', 'model.encoder.layers.encoder_layer_9.self_attention', 'model.encoder.layers.encoder_layer_9.self_attention.out_proj', 'model.encoder.layers.encoder_layer_9.mlp.0', 'model.encoder.layers.encoder_layer_9.mlp.3', 'model.encoder.layers.encoder_layer_10.self_attention', 'model.encoder.layers.encoder_layer_10.self_attention.out_proj', 'model.encoder.layers.encoder_layer_10.mlp.0', 'model.encoder.layers.encoder_layer_10.mlp.3', 'model.encoder.layers.encoder_layer_11.self_attention', 'model.encoder.layers.encoder_layer_11.self_attention.out_proj', 'model.encoder.layers.encoder_layer_11.mlp.0', 'model.encoder.layers.encoder_layer_11.mlp.3']
# Layers to sparsify: ['model.encoder.layers.encoder_layer_4.mlp.0', 'model.encoder.layers.encoder_layer_4.mlp.3', 'model.encoder.layers.encoder_layer_5.self_attention', 'model.encoder.layers.encoder_layer_5.self_attention.out_proj', 'model.encoder.layers.encoder_layer_5.mlp.0', 'model.encoder.layers.encoder_layer_5.mlp.3', 'model.encoder.layers.encoder_layer_6.self_attention', 'model.encoder.layers.encoder_layer_6.self_attention.out_proj', 'model.encoder.layers.encoder_layer_6.mlp.0', 'model.encoder.layers.encoder_layer_6.mlp.3'] (n=10)

# %%
import timm 

timms = timm.list_models(pretrained=True)
timms_moco = [t for t in timms if "moco" in t
timms_moco
# Out:
# False
